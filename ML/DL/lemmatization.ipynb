# %%
##to root words but valid words from dictionary.

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
#solves the issue stemming fails
#but need to choose noun,verb,etc
#and takes more time cause it has to compare
#to a corpus and give result.
###IMPORTANT NEED TO GIVE PARTS OF SPEECH TAG; pos as parameter

# %%
lemmatizer.lemmatize("fairly",pos = "v")
# Out:
# 'fairly'
